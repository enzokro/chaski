# %% [raw]
# ---
# author: enzokro
# badges: true
# categories:
# - TMP
# date: ''
# jupyter: python3
# output-file: index.html
# title: TITLE HERE
# toc: true
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# > Placeholder snippet

# %% [markdown]
# # Introduction

# %%
# lorem ipsum
